# %%
from wrangler import File

# %%
path = "/Users/gabriel.torres/Library/CloudStorage/OneDrive-FHNW/CDL1 Sensor Data/Messungen/Laufen/Gabriel_Torres/02_iPhone13ProMax-2023-02-24_13-13-16.json"
sensors = [
    "Accelerometer_x",
    "Accelerometer_y",
    "Accelerometer_z",
    "AccelerometerUncalibrated_x",
    "AccelerometerUncalibrated_y",
    "AccelerometerUncalibrated_z",
]

# import the data
file = File(path=path, sensors=sensors)
data = file.get_data()
data
# Out:
# shape: (12460, 10)
# ┌──────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────┬─────────┬──────────┐
# │ time     ┆ Accelerome ┆ Accelerome ┆ Accelerome ┆ ... ┆ Accelerome ┆ filena ┆ person  ┆ activity │
# │ ---      ┆ terUncalib ┆ terUncalib ┆ terUncalib ┆     ┆ ter_z      ┆ me     ┆ ---     ┆ ---      │
# │ datetime ┆ rated_x    ┆ rated_y    ┆ rated_z    ┆     ┆ ---        ┆ ---    ┆ str     ┆ str      │
# │ [ms]     ┆ ---        ┆ ---        ┆ ---        ┆     ┆ f32        ┆ str    ┆         ┆          │
# │          ┆ f32        ┆ f32        ┆ f32        ┆     ┆            ┆        ┆         ┆          │
# ╞══════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════╪═════════╪══════════╡
# │ 2023-02- ┆ 0.166824   ┆ -0.268387  ┆ -0.613327  ┆ ... ┆ 4.608505   ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.920  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ 0.240509   ┆ -0.300247  ┆ -0.75351   ┆ ... ┆ 3.34109    ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.930  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ 0.241714   ┆ -0.269623  ┆ -0.901489  ┆ ... ┆ 1.996242   ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.940  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ 0.194824   ┆ -0.226059  ┆ -0.941559  ┆ ... ┆ 0.551695   ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.950  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ ...      ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...    ┆ ...     ┆ ...      │
# │ 2023-02- ┆ -0.004028  ┆ -0.401306  ┆ -0.917038  ┆ ... ┆ 0.151378   ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:15 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :21.480  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ null       ┆ null       ┆ null       ┆ ... ┆ -0.36667   ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:15 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :21.490  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ -0.086502  ┆ -0.423325  ┆ -0.409302  ┆ ... ┆ null       ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.900  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# │ 2023-02- ┆ 0.032257   ┆ -0.217239  ┆ -0.451004  ┆ ... ┆ null       ┆ 02_iPh ┆ Gabriel ┆ Laufen   │
# │ 24 13:13 ┆            ┆            ┆            ┆     ┆            ┆ one13P ┆ _Torres ┆          │
# │ :16.910  ┆            ┆            ┆            ┆     ┆            ┆ roMax- ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2023-0 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 2-24_1 ┆         ┆          │
# │          ┆            ┆            ┆            ┆     ┆            ┆ 3-...  ┆         ┆          │
# └──────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────┴─────────┴──────────┘

# %%
# write to database
status = file.write_data(data, "test")
# print status of import
print("Write successful: ", status)
# Out:
# Write successful:  True
